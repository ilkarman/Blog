# %%
import urllib.request
import requests
# %matplotlib inline
from PIL import Image, ImageOps
from io import BytesIO
import matplotlib.pyplot as plt

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Get hippo
hippo_url = "https://i.ytimg.com/vi/96xC5JIkIpQ/maxresdefault.jpg"
urllib.request.urlretrieve(hippo_url, "test.jpg")
plt.imshow(Image.open("test.jpg"))
# Out:
# ('test.jpg', <http.client.HTTPMessage at 0x7f49aebf1b38>)

# %%
def show_rsp_image(resp):
    return Image.open(BytesIO(resp.content))

# %%
# Get styles
url = "http://0.0.0.0:5007/api/styles"
styles = requests.get(url).json()

# %%
for style in styles.keys():
    url = "http://0.0.0.0:5007/api/uploader/{0}".format(style)
    files = {'imagefile': open(fname, 'rb')}
    # %time out = requests.post(url, files=files)
    show_rsp_image(out)
# Out:
# CPU times: user 4.01 ms, sys: 2 ms, total: 6.01 ms
# Wall time: 1.5 s
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F49AEBC6668>
# CPU times: user 4.6 ms, sys: 0 ns, total: 4.6 ms
# Wall time: 1.26 s
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F49AEC0E630>
# CPU times: user 3.07 ms, sys: 1.04 ms, total: 4.11 ms
# Wall time: 1.54 s
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F49AEBEA588>
# CPU times: user 3.63 ms, sys: 381 µs, total: 4.01 ms
# Wall time: 1.36 s
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F49AEC545F8>
# CPU times: user 4.87 ms, sys: 0 ns, total: 4.87 ms
# Wall time: 1.37 s
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F49AEBEAA58>
# CPU times: user 3.81 ms, sys: 548 µs, total: 4.35 ms
# Wall time: 1.32 s
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F49AEBEA0F0>
